# %% [markdown]
# # Letnie igrzyska olimpijskie II
#
# ### 1.
#
#
# Wczytaj tabelę z dokonaniami medalowymi 'summer_1976_2008.pkl'.Wczytaj tabelę z dokonaniami medalowymi 'summer_1976_2008.pkl'.# Letnie igrzyska olimpijskie II

# %%
import pandas as pd
olimp = pd.read_pickle("summer_1976_2008.pkl")

# %% [markdown]
# ### 2.
#
# Jakie kraje zdobyły medale na igrzyskach olimpijskich w Moskwie, ale nie wzięły udziału (lub nie zdobyły żadnych medali) podczas igrzysk olimpijskich w Los Angeles?

# %%
set(olimp[olimp.City == 'Moscow']['Country'].unique())
# Out:
# {'Australia',
#  'Austria',
#  'Belgium',
#  'Brazil',
#  'Bulgaria',
#  'Cuba',
#  'Czechoslovakia',
#  'Denmark',
#  'East Germany',
#  'Ethiopia',
#  'Finland',
#  'France',
#  'Greece',
#  'Guyana',
#  'Hungary',
#  'India',
#  'Ireland',
#  'Italy',
#  'Jamaica',
#  'Korea, North',
#  'Lebanon',
#  'Mexico',
#  'Mongolia',
#  'Netherlands',
#  'Poland',
#  'Romania',
#  'Soviet Union',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Tanzania',
#  'Uganda',
#  'United Kingdom',
#  'Venezuela',
#  'Yugoslavia',
#  'Zimbabwe'}

# %%
Moskwa = set(olimp[olimp.City == 'Moscow']['Country'].unique())
Los_Angeles = set(olimp[olimp.City == 'Los Angeles']['Country'].unique())

# %%
Moskwa - Los_Angeles
# Out:
# {'Bulgaria',
#  'Cuba',
#  'Czechoslovakia',
#  'East Germany',
#  'Ethiopia',
#  'Guyana',
#  'Hungary',
#  'India',
#  'Korea, North',
#  'Lebanon',
#  'Mongolia',
#  'Poland',
#  'Soviet Union',
#  'Tanzania',
#  'Uganda',
#  'Zimbabwe'}

# %% [markdown]
# ### 3.
#
# Wyświetl wszystkich sportowców, którzy zdobyli medale na pięciu lub więcej olimpiadach.

# %%
olimp.head()
# Out:
#        City  Year     Sport Discipline           Event  \
# 0  Montreal  1976  Aquatics     Diving  3m springboard
# 1  Montreal  1976  Aquatics     Diving  3m springboard
# 2  Montreal  1976  Aquatics     Diving  3m springboard
# 3  Montreal  1976  Aquatics     Diving  3m springboard
# 4  Montreal  1976  Aquatics     Diving    10m platform
#
#                     Athlete Gender Country_Code        Country Event_gender  \
# 0           KÖHLER, Christa  Women          GDR   East Germany            W
# 1       KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2      BOGGS, Philip George    Men          USA  United States            M
# 3  CAGNOTTO, Giorgio Franco    Men          ITA          Italy            M
# 4    WILSON, Deborah Keplar  Women          USA  United States            W
#
#     Medal
# 0  Silver
# 1  Bronze
# 2    Gold
# 3  Silver
# 4  Bronze

# %%
o = olimp.loc[:, ['Athlete', 'Year']]
o
# Out:
#                         Athlete  Year
# 0               KÖHLER, Christa  1976
# 1           KOSENKOV, Aleksandr  1976
# 2          BOGGS, Philip George  1976
# 3      CAGNOTTO, Giorgio Franco  1976
# 4        WILSON, Deborah Keplar  1976
# ...                         ...   ...
# 15428        GUENOT, Christophe  2008
# 15429       KVIRKELIA, Manuchar  2008
# 15430          RAHIMOV, Vitaliy  2008
# 15431            GUENOT, Steeve  2008
# 15432             LOPEZ, Mijain  2008
#
# [15316 rows x 2 columns]

# %%
# Spr.
o[o.Athlete == 'TORRES, Dara']
# Out:
#             Athlete  Year
# 2896   TORRES, Dara  1984
# 4304   TORRES, Dara  1988
# 4334   TORRES, Dara  1988
# 5900   TORRES, Dara  1992
# 9431   TORRES, Dara  2000
# 9461   TORRES, Dara  2000
# 9493   TORRES, Dara  2000
# 9559   TORRES, Dara  2000
# 9560   TORRES, Dara  2000
# 13480  TORRES, Dara  2008
# 13541  TORRES, Dara  2008
# 13543  TORRES, Dara  2008

# %%
o.drop_duplicates(inplace=True)

# %%
o
# Out:
#                         Athlete  Year
# 0               KÖHLER, Christa  1976
# 1           KOSENKOV, Aleksandr  1976
# 2          BOGGS, Philip George  1976
# 3      CAGNOTTO, Giorgio Franco  1976
# 4        WILSON, Deborah Keplar  1976
# ...                         ...   ...
# 15428        GUENOT, Christophe  2008
# 15429       KVIRKELIA, Manuchar  2008
# 15430          RAHIMOV, Vitaliy  2008
# 15431            GUENOT, Steeve  2008
# 15432             LOPEZ, Mijain  2008
#
# [13909 rows x 2 columns]

# %%
o = o.Athlete.value_counts()
o
# Out:
# Athlete
# FISCHER, Birgit       6
# LIPA, Elisabeta       6
# SCHUMANN, Ralf        5
# TANI, Ryoko           5
# BURCICA, Constanta    5
#                      ..
# POPA, Celestina       1
# JENTSCH, Martina      1
# DOBRE, Aurelia        1
# MILLS, Phoebe Lan     1
# LOPEZ, Mijain         1
# Name: count, Length: 11337, dtype: Int64

# %%
o[o >= 5]
# Out:
# Athlete
# FISCHER, Birgit        6
# LIPA, Elisabeta        6
# SCHUMANN, Ralf         5
# TANI, Ryoko            5
# BURCICA, Constanta     5
# WANG, Yifu             5
# VAN GRUNSVEN, Anky     5
# EDWARDS, Teresa        5
# BORON, Kathrin         5
# OTTEY-PAGE, Merlene    5
# IGNAT, Doina           5
# IDEM, Josefa           5
# SAUTIN, Dmitry         5
# GRAEL, Torben          5
# GEORGESCU, Elena       5
# KOLOBKOV, Pavel        5
# TORRES, Dara           5
# REDGRAVE, Steven       5
# TRILLINI, Giovanna     5
# KARSTEN, Ekaterina     5
# Name: count, dtype: Int64

# %% [markdown]
# ### 4.
#
# Wyświetl wszystkich sportowców, którzy zdobyli medale w sześciu lub więcej konkurencjach medalowych.

# %%
e = olimp.loc[:, ['Athlete', 'Event']]
e
# Out:
#                         Athlete           Event
# 0               KÖHLER, Christa  3m springboard
# 1           KOSENKOV, Aleksandr  3m springboard
# 2          BOGGS, Philip George  3m springboard
# 3      CAGNOTTO, Giorgio Franco  3m springboard
# 4        WILSON, Deborah Keplar    10m platform
# ...                         ...             ...
# 15428        GUENOT, Christophe       66 - 74kg
# 15429       KVIRKELIA, Manuchar       66 - 74kg
# 15430          RAHIMOV, Vitaliy       55 - 60kg
# 15431            GUENOT, Steeve       60 - 66kg
# 15432             LOPEZ, Mijain      96 - 120kg
#
# [15316 rows x 2 columns]

# %%
e[e.Athlete == 'PHELPS, Michael']
# Out:
#                Athlete                   Event
# 11444  PHELPS, Michael          100m butterfly
# 11447  PHELPS, Michael  200m individual medley
# 11466  PHELPS, Michael  400m individual medley
# 11480  PHELPS, Michael  4x200m freestyle relay
# 11486  PHELPS, Michael  4x100m freestyle relay
# 11500  PHELPS, Michael     4x100m medley relay
# 11530  PHELPS, Michael          200m butterfly
# 11576  PHELPS, Michael          200m freestyle
# 13437  PHELPS, Michael          200m freestyle
# 13449  PHELPS, Michael  400m individual medley
# 13460  PHELPS, Michael     4x100m medley relay
# 13463  PHELPS, Michael          100m butterfly
# 13495  PHELPS, Michael          200m butterfly
# 13567  PHELPS, Michael  4x100m freestyle relay
# 13568  PHELPS, Michael  4x200m freestyle relay
# 13597  PHELPS, Michael  200m individual medley

# %%
e = e.Athlete.value_counts()
e[e>=6]
# Out:
# Athlete
# PHELPS, Michael          16
# TORRES, Dara             12
# THOMPSON, Jenny          12
# FISCHER, Birgit          12
# ANDRIANOV, Nikolay       12
#                          ..
# HELM, Rüdiger             6
# JOYNER-KERSEE, Jackie     6
# MARTINO, Angel            6
# OTTO, Kristin             6
# TRICKETT, Lisbeth         6
# Name: count, Length: 71, dtype: Int64

# %% [markdown]
# ### 5.
# **5 punktów**
#
# Wyświetl wszystkich sportowców, którzy zdobyli medale w dwóch różnych kategoriach *Sport*. Czy którekolwiek ze znalezionych nazwisk faktycznie reprezentuje jedną osobę? Da się to potwierdzić bazą?

# %%
s = olimp.loc[:, ['Athlete', 'Sport']]
s.head()
# Out:
#                     Athlete     Sport
# 0           KÖHLER, Christa  Aquatics
# 1       KOSENKOV, Aleksandr  Aquatics
# 2      BOGGS, Philip George  Aquatics
# 3  CAGNOTTO, Giorgio Franco  Aquatics
# 4    WILSON, Deborah Keplar  Aquatics

# %%
s.drop_duplicates(inplace=True)

# %%
olimp
# Out:
#            City  Year      Sport       Discipline           Event  \
# 0      Montreal  1976   Aquatics           Diving  3m springboard
# 1      Montreal  1976   Aquatics           Diving  3m springboard
# 2      Montreal  1976   Aquatics           Diving  3m springboard
# 3      Montreal  1976   Aquatics           Diving  3m springboard
# 4      Montreal  1976   Aquatics           Diving    10m platform
# ...         ...   ...        ...              ...             ...
# 15428   Beijing  2008  Wrestling  Wrestling Gre-R       66 - 74kg
# 15429   Beijing  2008  Wrestling  Wrestling Gre-R       66 - 74kg
# 15430   Beijing  2008  Wrestling  Wrestling Gre-R       55 - 60kg
# 15431   Beijing  2008  Wrestling  Wrestling Gre-R       60 - 66kg
# 15432   Beijing  2008  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                         Athlete Gender Country_Code        Country  \
# 0               KÖHLER, Christa  Women          GDR   East Germany
# 1           KOSENKOV, Aleksandr    Men          URS   Soviet Union
# 2          BOGGS, Philip George    Men          USA  United States
# 3      CAGNOTTO, Giorgio Franco    Men          ITA          Italy
# 4        WILSON, Deborah Keplar  Women          USA  United States
# ...                         ...    ...          ...            ...
# 15428        GUENOT, Christophe    Men          FRA         France
# 15429       KVIRKELIA, Manuchar    Men          GEO        Georgia
# 15430          RAHIMOV, Vitaliy    Men          AZE     Azerbaijan
# 15431            GUENOT, Steeve    Men          FRA         France
# 15432             LOPEZ, Mijain    Men          CUB           Cuba
#
#       Event_gender   Medal
# 0                W  Silver
# 1                M  Bronze
# 2                M    Gold
# 3                M  Silver
# 4                W  Bronze
# ...            ...     ...
# 15428            M  Bronze
# 15429            M    Gold
# 15430            M  Silver
# 15431            M    Gold
# 15432            M    Gold
#
# [15316 rows x 11 columns]

# %%
s = s.groupby('Athlete').size()
s[s>1]
# Out:
# Athlete
# BELOVA, Irina           2
# CHEN, Jing              2
# DIMITROV, Stefan        2
# GAVRILOV, Yuri          2
# GONZALEZ, Raul          2
# KOLESNIKOV, Nikolai     2
# KOVACS, Istvan          2
# KOVALENKO, Alexandre    2
# KUZNETSOV, Mikhail      2
# KUZNETSOV, Nikolai      2
# LEE, Eun Kyung          2
# LI, Na                  2
# LI, Ting                2
# OVCHINNIKOVA, Elena     2
# ROMERO, Rebecca         2
# THOMPSON, Richard       2
# TOMA, Sanda             2
# WANG, Liping            2
# WELLS, Matthew          2
# YANG, Wei               2
# YOUNG, Tim              2
# dtype: int64

# %%
olimp[olimp.Athlete == 'ROMERO, Rebecca']
# Out:
#           City  Year    Sport     Discipline  \
# 12906   Athens  2004   Rowing         Rowing
# 14284  Beijing  2008  Cycling  Cycling Track
#
#                                         Event          Athlete Gender  \
# 12906  quadruple sculls without coxswain (4x)  ROMERO, Rebecca  Women
# 14284                      individual pursuit  ROMERO, Rebecca  Women
#
#       Country_Code         Country Event_gender   Medal
# 12906          GBR  United Kingdom            W  Silver
# 14284          GBR  United Kingdom            W    Gold

# %% [markdown]
# ### 6.
#
# Utwórz wykres słupkowy pokazujący, ilu Polaków stanęło na podium podczas poszczególnych edycji igrzysk. Słupki ustaw w kolejności chronologicznej. Uwzględnij **wszystkie** olimpiady z bazy.

# %%
POL = olimp[olimp.Country == 'Poland']
POL
# Out:
#            City  Year          Sport       Discipline  \
# 187    Montreal  1976      Athletics        Athletics
# 195    Montreal  1976      Athletics        Athletics
# 208    Montreal  1976      Athletics        Athletics
# 224    Montreal  1976      Athletics        Athletics
# 239    Montreal  1976      Athletics        Athletics
# ...         ...   ...            ...              ...
# 14933   Beijing  2008         Rowing           Rowing
# 14962   Beijing  2008         Rowing           Rowing
# 14965   Beijing  2008         Rowing           Rowing
# 15348   Beijing  2008  Weightlifting    Weightlifting
# 15376   Beijing  2008      Wrestling  Wrestling Free.
#
#                                         Event                Athlete Gender  \
# 187                              4x400m relay            WERNER, Jan    Men
# 195                        3000m steeplechase  MALINOWSKI, Bronislaw    Men
# 208                              4x400m relay        PODLAS, Ryszard    Men
# 224                              4x400m relay        PIETRZYK, Jerzy    Men
# 239                                pole vault     SLUSARSKI, Tadeusz    Men
# ...                                       ...                    ...    ...
# 14933  quadruple sculls without coxswain (4x)    WASIELEWSKI, Konrad    Men
# 14962  quadruple sculls without coxswain (4x)            KOROL, Adam    Men
# 14965  quadruple sculls without coxswain (4x)       JELINSKI, Michal    Men
# 15348                                    94kg        KOLECKI, Szymon    Men
# 15376                               63 - 72kg   WIESZCZEK, Agnieszka  Women
#
#       Country_Code Country Event_gender   Medal
# 187            POL  Poland            M  Silver
# 195            POL  Poland            M  Silver
# 208            POL  Poland            M  Silver
# 224            POL  Poland            M  Silver
# 239            POL  Poland            M    Gold
# ...            ...     ...          ...     ...
# 14933          POL  Poland            M    Gold
# 14962          POL  Poland            M    Gold
# 14965          POL  Poland            M    Gold
# 15348          POL  Poland            M  Silver
# 15376          POL  Poland            W  Bronze
#
# [263 rows x 11 columns]

# %%
POL = POL.Year.value_counts()

# %%
POL
# Out:
# Year
# 1976    73
# 1980    50
# 1992    42
# 2000    24
# 1988    21
# 1996    21
# 2008    20
# 2004    12
# Name: count, dtype: int64

# %%
POL[1984] = 0

# %%
POL.sort_index().plot(kind='bar',figsize=(10,6));

# %% [markdown]
# ### 7.
#
# To samo co w punkcie 6., ale tym razem nad każdą edycją powinny znajdować się trzy słupki odpowiadające trzem rodzajom medali. Zadbaj, aby srebro było słupkiem środkowym.

# %%
POL = olimp[olimp.Country == 'Poland']
POL.groupby(['Year', 'Medal']).size().unstack()
# Out:
# Medal  Bronze  Gold  Silver
# Year
# 1976       26    18      29
# 1980       22     3      25
# 1988       10     2       9
# 1992       19     5      18
# 1996        7     7       7
# 2000        7     7      10
# 2004        6     4       2
# 2008        1     6      13

# %%
P = POL.groupby(['Year', 'Medal']).size().unstack()
P = P['Gold Silver Bronze'.split()]
P = P.plot(kind='bar', grid=True, figsize=(14,7), title='Klasyfikacja medalowa Polski w latach 1976-2008')
P.set_xlabel("Rok")
P.set_ylabel("Liczba medali");

# %% [markdown]
# ### 8.
#
# Z punktu 5. wynika, że podczas igrzysk w Montrealu na podium stanęło 73 Polaków. Jednak wg. [Wikipedii](https://pl.wikipedia.org/wiki/Letnie_Igrzyska_Olimpijskie_1976#Statystyka_medalowa) statystyka medalowa z tej olimpiady dla Polski to: złoto - 7, srebro - 6, brąz - 13, co daje zaledwie 26 medali. Dlaczego? Jak liczone są osiągnięcia medalowe dla krajów?
#
# Utwórz ramkę, w której zamieścisz oficjalne statystyki medalowe dla Polski dla wszystkich (poza edycją z roku 1984) igrzysk z bazy. W ramce:
# * wiersze to edycje olimpiady;
# * cztery kolumny odpowiadają wartościom: liczba złotych, srebrnych, brązowych medali i ich suma.
#
# Przykładowo, wiersz dla igrzysk z 1976 roku powinien mieć wartości 7, 6, 13, 26.

# %%
olimp[olimp.Country == 'Poland']
# Out:
#            City  Year          Sport       Discipline  \
# 187    Montreal  1976      Athletics        Athletics
# 195    Montreal  1976      Athletics        Athletics
# 208    Montreal  1976      Athletics        Athletics
# 224    Montreal  1976      Athletics        Athletics
# 239    Montreal  1976      Athletics        Athletics
# ...         ...   ...            ...              ...
# 14933   Beijing  2008         Rowing           Rowing
# 14962   Beijing  2008         Rowing           Rowing
# 14965   Beijing  2008         Rowing           Rowing
# 15348   Beijing  2008  Weightlifting    Weightlifting
# 15376   Beijing  2008      Wrestling  Wrestling Free.
#
#                                         Event                Athlete Gender  \
# 187                              4x400m relay            WERNER, Jan    Men
# 195                        3000m steeplechase  MALINOWSKI, Bronislaw    Men
# 208                              4x400m relay        PODLAS, Ryszard    Men
# 224                              4x400m relay        PIETRZYK, Jerzy    Men
# 239                                pole vault     SLUSARSKI, Tadeusz    Men
# ...                                       ...                    ...    ...
# 14933  quadruple sculls without coxswain (4x)    WASIELEWSKI, Konrad    Men
# 14962  quadruple sculls without coxswain (4x)            KOROL, Adam    Men
# 14965  quadruple sculls without coxswain (4x)       JELINSKI, Michal    Men
# 15348                                    94kg        KOLECKI, Szymon    Men
# 15376                               63 - 72kg   WIESZCZEK, Agnieszka  Women
#
#       Country_Code Country Event_gender   Medal
# 187            POL  Poland            M  Silver
# 195            POL  Poland            M  Silver
# 208            POL  Poland            M  Silver
# 224            POL  Poland            M  Silver
# 239            POL  Poland            M    Gold
# ...            ...     ...          ...     ...
# 14933          POL  Poland            M    Gold
# 14962          POL  Poland            M    Gold
# 14965          POL  Poland            M    Gold
# 15348          POL  Poland            M  Silver
# 15376          POL  Poland            W  Bronze
#
# [263 rows x 11 columns]

# %%
o = olimp[olimp.Country == 'Poland'].drop_duplicates(subset=['Event', 'Year', 'Discipline', 'Sport', 'Medal', 'Event_gender'])
o = o.groupby(['Year', 'Medal']).size().unstack()
o['Razem'] = o.Bronze + o.Silver + o.Gold 
o = o['Gold Silver Bronze Razem'.split()]
o
# Out:
# Medal  Gold  Silver  Bronze  Razem
# Year
# 1976      7       6      13     26
# 1980      3      14      15     32
# 1988      2       5       9     16
# 1992      3       6      10     19
# 1996      7       5       5     17
# 2000      6       5       3     14
# 2004      3       2       5     10
# 2008      3       6       1     10

# %% [markdown]
# Czy udało Ci się uzyskać pełną zgodność ze statystykami opublikowanymi na [Wikipedii](https://pl.wikipedia.org/wiki/Kategoria:Klasyfikacja_medalowa_letnich_igrzysk_olimpijskich)? Jeśli nie, to napisz co jest tego powodem.

# %% [markdown]
# Na podstawie ramki z tego punktu utwórz wykres słupkowy z **poziomymi** słupkami. Dla danej edycji trzy słupki powinny odpowiadać trzem rodzajom medali. Dostosuj rozmiar rysunku.

# %%
o.loc[:,['Gold', 'Silver', 'Bronze']].sort_index(ascending=False).plot(kind='barh', figsize=(16,9), grid=True)
# Out:
# <Axes: ylabel='Year'>

# %% [markdown]
# ### 9.
#
# Wykorzystaj bazę do utworzenia ramki z klasyfikacją medalową dla igrzysk z Montrealu. Klasyfikacja powinna wyglądać tak jak na [tej stronie](https://pl.wikipedia.org/wiki/Klasyfikacja_medalowa_Letnich_Igrzysk_Olimpijskich_1976) Wikipedii. Państwa mogą znajdować się w indeksie, liczbę porządkową możesz pominąć, ale zachowaj kolejność.

# %%
o = olimp[olimp.City == 'Montreal'].drop_duplicates(subset=['Event', 'Discipline', 'Sport', 'Medal', 'Country_Code', 'Event_gender'])
o = o.groupby(['Country', 'Medal']).size().unstack()
o.fillna(0, inplace=True)
o['Razem'] = o.Bronze + o.Silver + o.Gold 
o = o['Gold Silver Bronze Razem'.split()]
o.sort_values(by=['Gold','Silver','Bronze'], ascending=False)
# Out:
# Medal                Gold  Silver  Bronze  Razem
# Country
# Soviet Union         49.0    41.0    35.0  125.0
# East Germany         40.0    25.0    25.0   90.0
# United States        34.0    35.0    25.0   94.0
# West Germany         10.0    12.0    17.0   39.0
# Japan                 9.0     6.0    10.0   25.0
# Poland                7.0     6.0    13.0   26.0
# Bulgaria              6.0     9.0     7.0   22.0
# Cuba                  6.0     4.0     3.0   13.0
# Romania               4.0     9.0    14.0   27.0
# Hungary               4.0     5.0    13.0   22.0
# Finland               4.0     2.0     0.0    6.0
# Sweden                4.0     1.0     0.0    5.0
# United Kingdom        3.0     5.0     5.0   13.0
# Italy                 2.0     7.0     4.0   13.0
# France                2.0     3.0     4.0    9.0
# Yugoslavia            2.0     3.0     3.0    8.0
# Czechoslovakia        2.0     2.0     4.0    8.0
# New Zealand           2.0     1.0     1.0    4.0
# Korea, South          1.0     1.0     4.0    6.0
# Switzerland           1.0     1.0     2.0    4.0
# Jamaica               1.0     1.0     0.0    2.0
# Korea, North          1.0     1.0     0.0    2.0
# Norway                1.0     1.0     0.0    2.0
# Denmark               1.0     0.0     2.0    3.0
# Mexico                1.0     0.0     1.0    2.0
# Trinidad and Tobago   1.0     0.0     0.0    1.0
# Canada                0.0     5.0     6.0   11.0
# Belgium               0.0     3.0     3.0    6.0
# Netherlands           0.0     2.0     3.0    5.0
# Portugal              0.0     2.0     0.0    2.0
# Spain                 0.0     2.0     0.0    2.0
# Australia             0.0     1.0     4.0    5.0
# Iran                  0.0     1.0     1.0    2.0
# Mongolia              0.0     1.0     0.0    1.0
# Venezuela             0.0     1.0     0.0    1.0
# Brazil                0.0     0.0     2.0    2.0
# Austria               0.0     0.0     1.0    1.0
# Bermuda*              0.0     0.0     1.0    1.0
# Pakistan              0.0     0.0     1.0    1.0
# Puerto Rico*          0.0     0.0     1.0    1.0
# Thailand              0.0     0.0     1.0    1.0

# %% [markdown]
# Na podstawie ramki z tego punktu utwórz wykres słupkowy osiągnięć medalowych dla dwudziestu pierwszych krajów z tabeli. Znów każdy kraj powinien mieć trzy słupki odpowiadające trzem rodzajom medali. Słupki powinny być **pionowe**. Sprawdź, do czego służy parametr `rot` w metodzie `.plot()`. Wykorzystaj go, aby zwiększyć czytelność. Dostosuj rozmiar rysunku.

# %%
o = o.loc[:, ['Gold', 'Silver', 'Bronze']]
o.sort_values(by=['Gold', 'Silver', 'Bronze'], ascending=False).head(20).plot(kind='bar', figsize=(18,9), rot=30, grid=True)
# Out:
# <Axes: xlabel='Country'>
