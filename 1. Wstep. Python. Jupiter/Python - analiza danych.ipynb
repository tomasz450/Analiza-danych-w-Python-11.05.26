# %%
print('Hello b')
# Out:
# Hello b

# %%
lista = [1,2,3,4,5]
lista
# Out:
# [1, 2, 3, 4, 5]

# %%
for i in lista:
    if i % 2 ==0:
        print(i)
# Out:
# 2
# 4

# %%
4*3
# Out:
# 12

# %%
1 & 1 #AND
# Out:
# 1

# %%
1 | 0 # OR
# Out:
# 1

# %%
lista
# Out:
# [1, 2, 3, 4, 5]

# %%
lista[0]
# Out:
# 1

# %%
lista[-1]
# Out:
# 5

# %%
lista
# Out:
# [1, 2, 3, 4, 5]

# %%
lista[1:3]
# Out:
# [2, 3]

# %%
zmienna1 = "Napis" #string

# %%
zmienna1 = 1 #integer
type(zmienna1)
d = {'key1':'item1','key2':'item2'}
d['key1']
# Out:
# 'item1'
